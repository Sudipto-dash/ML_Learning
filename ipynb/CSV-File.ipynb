# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as ses
df = pd.read_csv('test.csv')
print(df)

# %%
print(df.head(5))

# %%
print(df.tail(5))

# %%
Embarking = df[(df['Embarked'] == 'Q')]

print(Embarking)

# %%
print(len(Embarking))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as ses
df = pd.read_csv('test.csv')
ses.barplot(y = df.Age, x=df.Sex )
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
ses.displot(df,x="Age")

# %%
fg = ses.load_dataset("penguins")
ses.displot(fg,x = "species")
#print(fg)

# %%
xg=ses.load_dataset("tips")
ses.displot(xg,x = "size",bins = [1,2,3,4,5,6])

# %%
ses.displot(fg, x = "flipper_length_mm",hue="species", element = "step")

# %%
ses.displot(fg, x = "flipper_length_mm" , kind = "kde", bw_adjust = .25)

# %%
ses.displot(fg, x = "flipper_length_mm" , kind = "kde",hue="species",multiple =  "stack",  bw_adjust = .75)

# %%
xg=ses.load_dataset("tips")
ses.displot(xg,x= "day",shrink = .5)

# %% [markdown]
# **Matplotlib**

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0, 5, .2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# **TITANIC***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as ses
df = pd.read_csv('test.csv')
x = df.Age
y = df.SibSp
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as ses
df = pd.read_csv('test.csv')

z = df.groupby(df["Pclass"])["Fare"].sum()
#plt.axis('equal')
plt.title("PClass and Fare")
plt.pie(z,labels=z.index,autopct='%1.1f%%', shadow=True, startangle=180)
plt.show()
